# %%
response ={
    "kind": "customsearch#search",
    "url": {
        "type": "application/json",
        "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
    },
    "queries": {
        "request": [
            {
                "title": "Google Custom Search - \"euro\", \"cờ bạc\", \"bóng đá\", \"tệ nạn\", \"cá cược\"",
                "totalResults": "368",
                "searchTerms": "\"euro\", \"cờ bạc\", \"bóng đá\", \"tệ nạn\", \"cá cược\"",
                "count": 10,
                "startIndex": 1,
                "language": "lang_vi",
                "inputEncoding": "utf8",
                "outputEncoding": "utf8",
                "safe": "off",
                "cx": "f7b7ab1f41c114b39",
                "dateRestrict": "m1"
            }
        ],
        "nextPage": [
            {
                "title": "Google Custom Search - \"euro\", \"cờ bạc\", \"bóng đá\", \"tệ nạn\", \"cá cược\"",
                "totalResults": "368",
                "searchTerms": "\"euro\", \"cờ bạc\", \"bóng đá\", \"tệ nạn\", \"cá cược\"",
                "count": 10,
                "startIndex": 11,
                "language": "lang_vi",
                "inputEncoding": "utf8",
                "outputEncoding": "utf8",
                "safe": "off",
                "cx": "f7b7ab1f41c114b39",
                "dateRestrict": "m1"
            }
        ]
    },
    "context": {
        "title": "searcg"
    },
    "searchInformation": {
        "searchTime": 0.145252,
        "formattedSearchTime": "0.15",
        "totalResults": "368",
        "formattedTotalResults": "368"
    },
    "items": [
        {
            "kind": "customsearch#result",
            "title": "Cảnh báo tệ nạn cá cược bóng đá mùa Euro",
            "htmlTitle": "Cảnh báo <b>tệ nạn cá cược bóng đá</b> mùa <b>Euro</b>",
            "link": "https://antv.gov.vn/phap-luat-3/canh-bao-te-nan-ca-cuoc-bong-da-mua-euro--9E6F5E63E.html",
            "displayLink": "antv.gov.vn",
            "snippet": "Jun 23, 2024 ... Cảnh báo tệ nạn cá cược bóng đá mùa Euro. BT. Chủ nhật, 23/06/2024 - 09:22 ... Cá độ bóng đá là hình thức cờ bạc đã tồn tại từ lâu, trong giai đoạn hiện ...",
            "htmlSnippet": "Jun 23, 2024 <b>...</b> Cảnh báo <b>tệ nạn cá cược bóng đá</b> mùa <b>Euro</b>. BT. Chủ nhật, 23/06/2024 - 09:22 ... Cá độ <b>bóng đá</b> là hình thức <b>cờ bạc</b> đã tồn tại từ lâu, trong giai đoạn hiện&nbsp;...",
            "formattedUrl": "https://antv.gov.vn/.../canh-bao-te-nan-ca-cuoc-bong-da-mua-euro--9E6F5...",
            "htmlFormattedUrl": "https://antv.gov.vn/.../canh-bao-te-nan-ca-cuoc-bong-da-mua-<b>euro</b>--9E6F5...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ2Rg5kg3U15oujLZLFvgn9_5jfxk5t4Lwt9QNKm4ePliKh1SZUl_TXntVi&s",
                        "width": "275",
                        "height": "183"
                    }
                ],
                "metatags": [
                    {
                        "og:image": "https://images.antv.gov.vn/public/uploads/2024/06/22/6676f4228c8dddbe559fcee6.jpg?w=600&h=400",
                        "copyright": "Copyright (c) by ANTV",
                        "og:image:width": "600",
                        "og:type": "article",
                        "viewport": "width=device-width, initial-scale=1.0",
                        "author": "ANTV",
                        "og:title": "Cảnh báo tệ nạn cá cược bóng đá mùa Euro",
                        "csrf-token": "i6Fo9pOj-B3iptDsJkpspmcfKLgFsHskuMbk",
                        "og:image:height": "315",
                        "language": "vi",
                        "og:image:type": "image/jpeg"
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://images.antv.gov.vn/public/uploads/2024/06/22/6676f4228c8dddbe559fcee6.jpg?w=600&h=400"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Đồng Tháp: Đấu tranh với tội phạm, tệ nạn cờ bạc mùa Euro năm ...",
            "htmlTitle": "Đồng Tháp: Đấu tranh với tội phạm, <b>tệ nạn cờ bạc</b> mùa <b>Euro</b> năm ...",
            "link": "https://bocongan.gov.vn/tin-tuc-su-kien/hoat-dong-cua-luc-luong-cong-an/hoat-dong-cua-dia-phuong/dong-thap-dau-tranh-voi-toi-pham-te-nan-co-bac-mua-euro-nam-2024-d23-t40104.html",
            "displayLink": "bocongan.gov.vn",
            "snippet": "15 hours ago ... Đồng Tháp: Đấu tranh với tội phạm, tệ nạn cờ bạc mùa Euro năm 2024. 12/07 ... cá cược bóng đá. Để ngăn chặn, đấu tranh có hiệu quả với các loại tội phạm ...",
            "htmlSnippet": "15 hours ago <b>...</b> Đồng Tháp: Đấu tranh với tội phạm, <b>tệ nạn cờ bạc</b> mùa <b>Euro</b> năm 2024. 12/07 ... <b>cá cược bóng đá</b>. Để ngăn chặn, đấu tranh có hiệu quả với các loại tội phạm&nbsp;...",
            "formattedUrl": "https://bocongan.gov.vn/.../dong-thap-dau-tranh-voi-toi-pham-te-nan-co-b...",
            "htmlFormattedUrl": "https://bocongan.gov.vn/.../dong-thap-dau-tranh-voi-toi-pham-te-nan-co-b...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGw6UwK4VjlSJJ2vqo3ANdjcGB-JNXEi0e67OImt5fovvR5uzrAYqg_FA&s=0",
                        "width": "149",
                        "height": "99"
                    }
                ],
                "metatags": [
                    {
                        "dc.publisher": "https://mps.gov.vn",
                        "og:image": "https://bocongan.gov.vn/knd/tt/PublishingImages/Hoàng Thị Thanh/104_doi tuong tham gia lac tài xiu(1).jpg",
                        "twitter:title": "Đồng Tháp: Đấu tranh với tội phạm, tệ nạn cờ bạc mùa Euro năm 2024",
                        "dc.description": "Trang chủ, Home",
                        "copyright": "Bộ Công an",
                        "twitter:url": "https://bocongan.gov.vn/tin-tuc-su-kien/hoat-dong-cua-luc-luong-cong-an/hoat-dong-cua-dia-phuong/dong-thap-dau-tranh-voi-toi-pham-te-nan-co-bac-mua-euro-nam-2024-d23-t40104.html",
                        "author": "Bộ Công an",
                        "og:title": "Đồng Tháp: Đấu tranh với tội phạm, tệ nạn cờ bạc mùa Euro năm 2024",
                        "apple-mobile-web-app-title": "mps.gov.vn",
                        "og:description": "Nhờ chủ động phòng ngừa, đấu tranh có hiệu quả với các loại tội phạm, tệ nạn xã hội mà từ mùa giải bóng đá Euro năm 2024 đến nay, Công an toàn tỉnh Đồng Tháp đã triệt xóa nhiều vụ cờ bạc, điều tra khám phá nhiều vụ trộm cắp...",
                        "twitter:image": "https://bocongan.gov.vn/knd/tt/PublishingImages/Hoàng Thị Thanh/104_doi tuong tham gia lac tài xiu(1).jpg",
                        "dc.created": "2017-12-01T00-00-00",
                        "viewport": "width=device-width, initial-scale=1.0, user-scalable=yes",
                        "twitter:description": "Nhờ chủ động phòng ngừa, đấu tranh có hiệu quả với các loại tội phạm, tệ nạn xã hội mà từ mùa giải bóng đá Euro năm 2024 đến nay, Công an toàn tỉnh Đồng Tháp đã triệt xóa nhiều vụ cờ bạc, điều tra khám phá nhiều vụ trộm cắp...",
                        "dc.creator": "Bộ Công An",
                        "apple-mobile-web-app-capable": "yes",
                        "dc.identifier": "https://mps.gov.vn",
                        "dc.subject": "Trang chủ, Home",
                        "og:url": "https://bocongan.gov.vn/tin-tuc-su-kien/hoat-dong-cua-luc-luong-cong-an/hoat-dong-cua-dia-phuong/dong-thap-dau-tranh-voi-toi-pham-te-nan-co-bac-mua-euro-nam-2024-d23-t40104.html",
                        "dc.language": "vie",
                        "format-detection": "telephone=no"
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://bocongan.gov.vn/knd/tt/PublishingImages/Ho%C3%A0ng%20Th%E1%BB%8B%20Thanh/104_doi%20tuong%20tham%20gia%20lac%20t%C3%A0i%20xiu(1).jpg?width=1000"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Tổ chức hoạt động tuyên truyền phòng chống tội phạm, vi phạm ...",
            "htmlTitle": "Tổ chức hoạt động tuyên truyền phòng chống tội phạm, vi phạm ...",
            "link": "http://congan.daklak.gov.vn/-/to-chuc-hoat-ong-tuyen-truyen-phong-chong-toi-pham-vi-pham-phap-luat-lien-quan-en-co-bac-ca-o-bong-a-vong-chung-ket-euro-2024",
            "displayLink": "congan.daklak.gov.vn",
            "snippet": "Jul 3, 2024 ... ... EURO 2024 nói riêng và các giải bóng đá Quốc tế nói chung. Các cơ sở ... tệ nạn cờ bạc trên địa bàn. Cơ sở kinh doanh chủ động dán thông báo về việc ...",
            "htmlSnippet": "Jul 3, 2024 <b>...</b> ... <b>EURO</b> 2024 nói riêng và các giải <b>bóng đá</b> Quốc tế nói chung. Các cơ sở ... <b>tệ nạn cờ bạc</b> trên địa bàn. Cơ sở kinh doanh chủ động dán thông báo về việc&nbsp;...",
            "formattedUrl": "http://congan.daklak.gov.vn/-/to-chuc-hoat-ong-tuyen-truyen-phong-chon...",
            "htmlFormattedUrl": "http://congan.daklak.gov.vn/-/to-chuc-hoat-ong-tuyen-truyen-phong-chon...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTcDdH4qvVER0OWKffHVENdsPUvVQbt4pll8owSm7j7-GsVjhvwsZxwLA&s",
                        "width": "584",
                        "height": "86"
                    }
                ],
                "metatags": [
                    {
                        "viewport": "width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no",
                        "apple-mobile-web-app-capable": "yes"
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://congan.daklak.gov.vn/image/layout_set_logo?img_id=149338&t=1719745986486"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Cá độ nở rộ mùa Euro",
            "htmlTitle": "Cá độ nở rộ mùa <b>Euro</b>",
            "link": "https://congan.com.vn/vu-an/phong-su/ca-do-no-ro-mua-euro_163552.html",
            "displayLink": "congan.com.vn",
            "snippet": "Jun 17, 2024 ... Thủ Đức) bị kẻ gian xịt sơn lem luốc, quảng bá tên các website cá độ bóng đá, cờ bạc. ... cá cược bóng đá qua mạng. Tại Việt Nam, hành vi đánh bạc (trong đó có cá ...",
            "htmlSnippet": "Jun 17, 2024 <b>...</b> Thủ Đức) bị kẻ gian xịt sơn lem luốc, quảng bá tên các website cá độ <b>bóng đá</b>, <b>cờ bạc</b>. ... <b>cá cược bóng đá</b> qua mạng. Tại Việt Nam, hành vi đánh bạc (trong đó có cá&nbsp;...",
            "formattedUrl": "https://congan.com.vn/vu-an/phong.../ca-do-no-ro-mua-euro_163552.html",
            "htmlFormattedUrl": "https://congan.com.vn/vu-an/phong.../ca-do-no-ro-mua-<b>euro</b>_163552.html",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ8LhWCdMZYCkKsU_EkZT-605HxXZDxs7afIiDRQebFYLAomcOm8--BeYVR&s",
                        "width": "290",
                        "height": "174"
                    }
                ],
                "metatags": [
                    {
                        "webdesign": "http://vgroup.vn",
                        "og:image": "https://cloud.tienlenquyetthang.com/thumbnail/CATP-480-2024-6-17/5a-1_1654_992_989.jpg",
                        "copyright": "Báo Công an Thành Phố Hồ Chí Minh",
                        "og:type": "article",
                        "og:image:alt": "https://cloud.tienlenquyetthang.com/thumbnail/CATP-480-2024-6-17/5a-1_1654_992_989.jpg",
                        "og:image:width": "480",
                        "article:section": "Phóng sự",
                        "og:site_name": "Báo Công an Thành Phố Hồ Chí Minh",
                        "author": "congan.com.vn",
                        "apple-mobile-web-app-title": "congan.com.vn",
                        "og:title": "Cá độ nở rộ mùa Euro",
                        "og:image:height": "288",
                        "fb:pages": "835437133180903",
                        "og:description": "(CATP) Giải vô địch bóng đá Châu Âu 2024 (Euro 2024) đang diễn ra và Giải vô địch bóng đá Nam Mỹ 2024 (Copa America 2024) sắp tới là hai sự kiện thu...",
                        "article:author": "https://www.facebook.com/BaoConganTP.HCM",
                        "article:tag": "Cá độ",
                        "fb:app_id": "989798167762726",
                        "viewport": "width=device-width, initial-scale=1.0, user-scalable=yes",
                        "apple-mobile-web-app-capable": "yes",
                        "og:url": "https://congan.com.vn/vu-an/phong-su/ca-do-no-ro-mua-euro_163552.html",
                        "lastmod": "2024-06-17T15:49+07:00",
                        "pubdate": "2024-06-17T09:22+07:00"
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://cloud.tienlenquyetthang.com/thumbnail/CATP-480-2024-6-17/5a-1_1654_992_989.jpg"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Phòng ngừa nạn cá cược trong mùa Euro 2024 - Báo Bình Dương ...",
            "htmlTitle": "Phòng ngừa nạn <b>cá cược</b> trong mùa <b>Euro</b> 2024 - Báo Bình Dương ...",
            "link": "https://baobinhduong.vn/phong-ngua-nan-ca-cuoc-trong-mua-euro-2024-a324538.html",
            "displayLink": "baobinhduong.vn",
            "snippet": "Jun 17, 2024 ... Khi giải vô địch bóng đá châu Âu 2024 (Euro 2024) chính thức khai mạc vào giữa tháng 6 cũng là dịp phát sinh tệ nạn cờ bạc dưới hình thức cá cược.",
            "htmlSnippet": "Jun 17, 2024 <b>...</b> Khi giải vô địch <b>bóng đá</b> châu Âu 2024 (<b>Euro</b> 2024) chính thức khai mạc vào giữa tháng 6 cũng là dịp phát sinh <b>tệ nạn cờ bạc</b> dưới hình thức <b>cá cược</b>.",
            "formattedUrl": "https://baobinhduong.vn/phong-ngua-nan-ca-cuoc-trong-mua-euro-2024-a...",
            "htmlFormattedUrl": "https://baobinhduong.vn/phong-ngua-nan-ca-cuoc-trong-mua-<b>euro</b>-2024-a...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQtlhexS-CIQbsLgpY2TT4kTMSJvEPkcggisV-WmR9IV7jIb7-s0HDd7SY&s",
                        "width": "259",
                        "height": "194"
                    }
                ],
                "metatags": [
                    {
                        "og:image": "https://baobinhduong.vn/image/news/2024/20240617/thumbnail/475x300/1718587172.jpg",
                        "og:type": "article",
                        "og:title": "Phòng ngừa nạn cá cược trong mùa Euro 2024",
                        "og:locale": "vi_VN",
                        "og:url": "https://baobinhduong.vn/phong-ngua-nan-ca-cuoc-trong-mua-euro-2024-a324538.html",
                        "og:description": "Khi giải vô địch bóng đá châu Âu 2024 (Euro 2024) chính thức khai mạc vào giữa tháng 6 cũng là dịp phát sinh tệ nạn cờ bạc dưới hình thức cá cược."
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://baobinhduong.vn/image/news/2024/20240617/thumbnail/475x300/1718587172.jpg"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Chủ động phòng ngừa cá độ bóng đá - Báo điện tử Bình Định",
            "htmlTitle": "Chủ động phòng ngừa cá độ <b>bóng đá</b> - Báo điện tử Bình Định",
            "link": "https://baobinhdinh.vn/viewer.aspx?macm=15&macmp=16&mabb=279236",
            "displayLink": "baobinhdinh.vn",
            "snippet": "Jun 26, 2024 ... Để ngăn ngừa tệ nạn cờ bạc dưới hình thức cá cược, cá độ bóng đá có nguy cơ xuất hiện trong thời gian diễn ra giải vô địch bóng đá Châu Âu 2024 (EURO 2024) ...",
            "htmlSnippet": "Jun 26, 2024 <b>...</b> Để ngăn ngừa <b>tệ nạn cờ bạc</b> dưới hình thức <b>cá cược</b>, cá độ <b>bóng đá</b> có nguy cơ xuất hiện trong thời gian diễn ra giải vô địch <b>bóng đá</b> Châu Âu 2024 (<b>EURO</b> 2024)&nbsp;...",
            "formattedUrl": "https://baobinhdinh.vn/viewer.aspx?macm=15&macmp=16&mabb...",
            "htmlFormattedUrl": "https://baobinhdinh.vn/viewer.aspx?macm=15&amp;macmp=16&amp;mabb...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRu0-Z91I8pi87_YmSQDZGhyfeTNdogvkpRfGBM5hW1fWjcUCJbeZhqDeo7&s",
                        "width": "254",
                        "height": "199"
                    }
                ],
                "metatags": [
                    {
                        "og:img": "http://baobinhdinh.com.vn/media/15/16/279236/278634.jpg",
                        "fb:app_id": "1634155666825162",
                        "og:type": "website",
                        "og:site_name": "BBD-Tin tức hay",
                        "og:title": "Chủ động phòng ngừa cá độ bóng đá",
                        "og:url": "http://baobinhdinh.com.vn/viewer.aspx?macm=15&macmp=16&mabb=279236",
                        "og:description": "<p>Để ngăn ngừa tệ nạn cờ bạc dưới hình thức cá cược, cá độ bóng đá có nguy cơ xuất hiện trong thời gian diễn ra giải vô địch bóng đá Châu Âu 2024 (EURO 2024), Công an các đơn vị, địa phương đã tăng cường cảnh báo, tuyên truyền nâng cao nhận thức của người dân và các biện pháp phòng ngừa, góp phần đảm bảo an ninh trật tự trên địa bàn."
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://baobinhdinh.vn/viewimage.aspx?imgid=278634"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Đừng để “mùa EURO” thành canh bạc",
            "htmlTitle": "Đừng để “mùa <b>EURO</b>” thành canh bạc",
            "link": "https://vovgiaothong.vn/newsaudio/dung-de-mua-euro-thanh-canh-bac-d39585.html",
            "displayLink": "vovgiaothong.vn",
            "snippet": "Jun 28, 2024 ... Từng dính vào cá cược bóng đá trên mạng, anh Hà (ngụ quận Bình Thạnh) đã ... “Mình khuyên các bạn là đừng nên dính vào cờ bạc hay bóng đá, hay là đá gà ...",
            "htmlSnippet": "Jun 28, 2024 <b>...</b> Từng dính vào <b>cá cược bóng đá</b> trên mạng, anh Hà (ngụ quận Bình Thạnh) đã ... “Mình khuyên các bạn là đừng nên dính vào <b>cờ bạc</b> hay <b>bóng đá</b>, hay là đá gà&nbsp;...",
            "formattedUrl": "https://vovgiaothong.vn/.../dung-de-mua-euro-thanh-canh-bac-d39585.htm...",
            "htmlFormattedUrl": "https://vovgiaothong.vn/.../dung-de-mua-<b>euro</b>-thanh-canh-bac-d39585.htm...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTt91X7KQApRsBCqdqpk_fKvX_SbSyjajpT5wg__L5Ld0XgJH4WJlqpYYKM&s",
                        "width": "300",
                        "height": "168"
                    }
                ],
                "metatags": [
                    {
                        "og:image": "https://t.ex-cdn.com/vovgiaothong.vn/560w/files/news/2024/06/28/1-60giay-071032.jpg",
                        "copyright": "vovgiaothong.vn",
                        "og:type": "article",
                        "article:section": "News",
                        "viewport": "width=device-width, initial-scale=1.0, user-scalable=yes",
                        "author": "vovgiaothong.vn",
                        "og:title": "Đừng để “mùa EURO” thành canh bạc",
                        "alexaverifyid": "IyOAWrtFdNQSVZO_gDBWnsEy8n8",
                        "og:url": "https://vovgiaothong.vn/newsaudio/dung-de-mua-euro-thanh-canh-bac-d39585.html",
                        "fb:pages": "303745000298569",
                        "og:description": "Vòng chung kết giải bóng đá vô địch châu Âu  (Euro 2024) và giải vô địch bóng đá Nam Mỹ (Copa America 2024) đã bắt đầu, người hâm mộ bóng đá háo hức chờ đợi những bữa tiệc bóng đá mãn nhãn trên sân cỏ.",
                        "article:tag": "cá độ bóng đá,mùa Euro,tội phạm,mạng xã hội,hành vi"
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://t.ex-cdn.com/vovgiaothong.vn/560w/files/news/2024/06/28/1-60giay-071032.jpg"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "LỊCH THI ĐẤU EURO 2024; cảnh báo tội phạm cá độ bóng đá",
            "htmlTitle": "LỊCH THI ĐẤU <b>EURO</b> 2024; cảnh báo tội phạm cá độ <b>bóng đá</b>",
            "link": "https://xaydungchinhsach.chinhphu.vn/lich-thi-dau-uefa-euro-2024-cong-an-canh-bao-toi-pham-ca-do-119240614082933142.htm",
            "displayLink": "xaydungchinhsach.chinhphu.vn",
            "snippet": "6 days ago ... ... tệ nạn xã hội, kiên quyết tránh xa cá độ bóng đá. Quan tâm, quản lý ... Vì sao chưa thực hiện Nghị định về cá cược bóng đá, đua chó,. Tham khảo thêm ...",
            "htmlSnippet": "6 days ago <b>...</b> ... <b>tệ nạn</b> xã hội, kiên quyết tránh xa cá độ <b>bóng đá</b>. Quan tâm, quản lý ... Vì sao chưa thực hiện Nghị định về <b>cá cược bóng đá</b>, đua chó,. Tham khảo thêm&nbsp;...",
            "formattedUrl": "https://xaydungchinhsach.chinhphu.vn/lich-thi-dau-uefa-euro-2024-cong-a...",
            "htmlFormattedUrl": "https://xaydungchinhsach.chinhphu.vn/lich-thi-dau-uefa-<b>euro</b>-2024-cong-a...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBKAh8nQZ8JB4JySRng8sFpdLgrv4aV-NnBYmtdD0eoNBXcNs8zJS9c5s&s",
                        "width": "310",
                        "height": "163"
                    }
                ],
                "metatags": [
                    {
                        "og:image": "https://xdcs.cdnchinhphu.vn/zoom/600_315/446259493575335936/2024/6/15/euro-2024-draw-8279-17183342641731415077565-17184492784552010887134-0-29-571-943-crop-17184492881571748912276.jpg",
                        "copyright": "© Cổng Thông tin điện tử Chính phủ",
                        "og:type": "website",
                        "og:image:width": "600",
                        "og:site_name": "xaydungchinhsach.chinhphu.vn",
                        "author": "xaydungchinhsach.chinhphu.vn",
                        "og:title": "LỊCH THI ĐẤU EURO 2024; cảnh báo tội phạm cá độ bóng đá",
                        "og:image:height": "315",
                        "og:image:type": "image/png",
                        "og:description": "Chi tiết LỊCH THI ĐẤU UEFA Euro 2024. Cảnh báo của Cơ quan Công an về tội phạm đánh bạc, tổ chức đánh bạc dưới hình thức cá độ bóng đá.",
                        "referrer": "no-referrer-when-downgrade",
                        "apple-mobile-web-app-status-bar-style": "black",
                        "news_keywords": "LỊCH THI ĐẤU UEFA Euro 2024, c&#225; độ, đ&#225;nh bạc, C&#244;ng an, cảnh b&#225;o, Lịch thi đấu Copa America 2024, c&#225; độ b&#243;ng đ&#225;, bảng xếp hạng EURO 2024",
                        "viewport": "width=device-width, initial-scale=1.0",
                        "apple-mobile-web-app-capable": "yes",
                        "og:rich_attachment": "true",
                        "og:url": "https://xaydungchinhsach.chinhphu.vn/lich-thi-dau-uefa-euro-2024-cong-an-canh-bao-toi-pham-ca-do-119240614082933142.htm",
                        "format-detection": "telephone=no"
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://xdcs.cdnchinhphu.vn/zoom/600_315/446259493575335936/2024/6/15/euro-2024-draw-8279-17183342641731415077565-17184492784552010887134-0-29-571-943-crop-17184492881571748912276.jpg"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Dân Sinh - Bùng phát nạn cá cược mùa Euro | Báo Dân Trí",
            "htmlTitle": "Dân Sinh - Bùng phát nạn <b>cá cược</b> mùa <b>Euro</b> | Báo Dân Trí",
            "link": "https://dansinh.dantri.com.vn/dien-dan-dan-sinh/bung-phat-nan-ca-cuoc-mua-euro-20240627231946740.htm",
            "displayLink": "dansinh.dantri.com.vn",
            "snippet": "Jun 27, 2024 ... Bùng phát nạn cá cược mùa Euro. LĐXH Thứ năm, 27/06/2024 - 23:23 ... bóng đá Euro 2024. Sau đó, các nghi phạm phân bổ, chia nhỏ tài khoản với hạn ...",
            "htmlSnippet": "Jun 27, 2024 <b>...</b> Bùng phát nạn <b>cá cược</b> mùa <b>Euro</b>. LĐXH Thứ năm, 27/06/2024 - 23:23 ... <b>bóng đá Euro</b> 2024. Sau đó, các nghi phạm phân bổ, chia nhỏ tài khoản với hạn&nbsp;...",
            "formattedUrl": "https://dansinh.dantri.com.vn/.../bung-phat-nan-ca-cuoc-mua-euro-202406...",
            "htmlFormattedUrl": "https://dansinh.dantri.com.vn/.../bung-phat-nan-ca-cuoc-mua-<b>euro</b>-202406...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWzcezuiFcxfZz-q9zbrNcwgu7EewD5eM7C9EzjvOFtePEGaa21la1yCA&s",
                        "width": "290",
                        "height": "174"
                    }
                ],
                "metatags": [
                    {
                        "og:image": "https://icdn.dantri.com.vn/dansinh/2024/06/27/z5580623000353da6c568aaa6776378b6842a98ff5a097-1719505040292.jpg",
                        "twitter:card": "summary_large_image",
                        "twitter:title": "Dân Sinh - Bùng phát nạn cá cược mùa Euro | Báo Dân Trí",
                        "viewport": "width=device-width, initial-scale=1",
                        "og:title": "Dân Sinh - Bùng phát nạn cá cược mùa Euro | Báo Dân Trí",
                        "twitter:image": "https://icdn.dantri.com.vn/dansinh/2024/06/27/z5580623000353da6c568aaa6776378b6842a98ff5a097-1719505040292.jpg"
                    }
                ],
                "cse_image": [
                    {
                        "src": "https://icdn.dantri.com.vn/dansinh/2024/06/27/z5580623000353da6c568aaa6776378b6842a98ff5a097-1719505040292.jpg"
                    }
                ]
            }
        },
        {
            "kind": "customsearch#result",
            "title": "Cảnh báo gia tăng các hình thức lừa đảo trên không gian mạng ...",
            "htmlTitle": "Cảnh báo gia tăng các hình thức lừa đảo trên không gian mạng ...",
            "link": "https://m.antoanthongtin.vn/an-toan-thong-tin/canh-bao-gia-tang-cac-hinh-thuc-lua-dao-tren-khong-gian-mang-trong-mua-euro-2024-110300",
            "displayLink": "m.antoanthongtin.vn",
            "snippet": "Jul 3, 2024 ... ... cá cược các trận bóng đá, mùa giải Euro… Đường dây này thường xuyên ... Tệ nạn cờ bạc với hình thức cá độ bóng đá gây ra rất nhiều hệ lụy, ảnh hưởng ...",
            "htmlSnippet": "Jul 3, 2024 <b>...</b> ... <b>cá cược</b> các trận <b>bóng đá</b>, mùa giải <b>Euro</b>… Đường dây này thường xuyên ... <b>Tệ nạn cờ bạc</b> với hình thức cá độ <b>bóng đá</b> gây ra rất nhiều hệ lụy, ảnh hưởng&nbsp;...",
            "formattedUrl": "https://m.antoanthongtin.vn/.../canh-bao-gia-tang-cac-hinh-thuc-lua-dao-tre...",
            "htmlFormattedUrl": "https://m.antoanthongtin.vn/.../canh-bao-gia-tang-cac-hinh-thuc-lua-dao-tre...",
            "pagemap": {
                "cse_thumbnail": [
                    {
                        "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRwFXNjeLA7HFoC4PaC9AFeAj_Xid99quQTZ5o39EtWMIg066r13t6QtLdf&s",
                        "width": "302",
                        "height": "167"
                    }
                ],
                "metatags": [
                    {
                        "og:image": "http://tailieu.antoanthongtin.vn/files/images/site-2/20240626/canh-bao-gia-tang-cac-hinh-thuc-lua-dao-tren-khong-gian-mang-trong-mua-euro-2024-2-26062024101218.jpg",
                        "apple-itunes-app": "app-id = 1239481550, affiliate-data = myAffiliateData, app-argument = https://itunes.apple.com/vn/app/t%E1%BA%A1p-ch%C3%AD-attt/id1239481550?mt=8",
                        "og:type": "website",
                        "og:site_name": "An Toan Thong Tin",
                        "viewport": "width=device-width, initial-scale=1.0",
                        "author": "An Toàn Thông Tin",
                        "og:title": "Cảnh báo gia tăng các hình thức lừa đảo trên không gian mạng trong mùa EURO 2024 - An Toàn Thông Tin",
                        "rating": "general",
                        "og:url": "http://antoanthongtin.gov.vn/an-toan-thong-tin/chi-tiet-bai-viet-cua-110300",
                        "og:description": "Giải vô địch bóng đá Châu Âu (EURO 2024) sự kiện thể thao, giải trí lớn, thu hút đông đảo người hâm mộ trên thế giới trong đó có Việt Nam. Tuy nhiên, đây cũng là điều kiện để tội phạm cá độ bóng đá hoạt động phức tạp hơn, đặc biệt cá độ bóng đá trên không gian mạng.",
                        "google-play-app": "app-id = vn.actvn.sois.news"
                    }
                ],
                "cse_image": [
                    {
                        "src": "http://tailieu.antoanthongtin.vn/files/images/site-2/20240626/canh-bao-gia-tang-cac-hinh-thuc-lua-dao-tren-khong-gian-mang-trong-mua-euro-2024-2-26062024101218.jpg"
                    }
                ]
            }
        }
    ]
}

# %%
def extract_keywords(data):
    search_terms = data["queries"]["request"][0]["searchTerms"]
    keywords = search_terms.replace("\"", "").split(", ")
    modified_keywords = [keyword.replace(" ", "_") for keyword in keywords]
    return modified_keywords


def extract_urls(response):
    urls = []
    if 'items' in response and len(response['items']) > 0:
        for item in response['items']:
            if 'link' in item:
                urls.append(item['link'])
    return urls
# Out:
# ['euro', 'cờ_bạc', 'bóng_đá', 'tệ_nạn', 'cá_cược']

# %%
# Trích xuất

# %%
def extract_urls(response):
    urls = []
    if 'items' in response and len(response['items']) > 0:
        for item in response['items']:
            if 'link' in item:
                urls.append(item['link'])
    return urls

# Sử dụng hàm với biến response được định nghĩa ở trên
urls = extract_urls(response)
print(urls)
# Out:
# ['https://antv.gov.vn/phap-luat-3/canh-bao-te-nan-ca-cuoc-bong-da-mua-euro--9E6F5E63E.html', 'https://bocongan.gov.vn/tin-tuc-su-kien/hoat-dong-cua-luc-luong-cong-an/hoat-dong-cua-dia-phuong/dong-thap-dau-tranh-voi-toi-pham-te-nan-co-bac-mua-euro-nam-2024-d23-t40104.html', 'http://congan.daklak.gov.vn/-/to-chuc-hoat-ong-tuyen-truyen-phong-chong-toi-pham-vi-pham-phap-luat-lien-quan-en-co-bac-ca-o-bong-a-vong-chung-ket-euro-2024', 'https://congan.com.vn/vu-an/phong-su/ca-do-no-ro-mua-euro_163552.html', 'https://baobinhduong.vn/phong-ngua-nan-ca-cuoc-trong-mua-euro-2024-a324538.html', 'https://baobinhdinh.vn/viewer.aspx?macm=15&macmp=16&mabb=279236', 'https://vovgiaothong.vn/newsaudio/dung-de-mua-euro-thanh-canh-bac-d39585.html', 'https://xaydungchinhsach.chinhphu.vn/lich-thi-dau-uefa-euro-2024-cong-an-canh-bao-toi-pham-ca-do-119240614082933142.htm', 'https://dansinh.dantri.com.vn/dien-dan-dan-sinh/bung-phat-nan-ca-cuoc-mua-euro-20240627231946740.htm', 'https://m.antoanthongtin.vn/an-to
# ...

# %%
# Khởi tạo mảng array_of_elements và cập nhật các phần tử với thuộc tính 'url'
array_of_elements = [{'url': url,'title':"", 'content': '','labeled_pos':[],'extract_content': [], 'cosine_degree': 0.0} for url in urls]

# Hiển thị mảng array_of_elements sau khi cập nhật
print(array_of_elements)
# Out:
# [{'url': 'https://antv.gov.vn/phap-luat-3/canh-bao-te-nan-ca-cuoc-bong-da-mua-euro--9E6F5E63E.html', 'title': '', 'content': '', 'labeled_pos': [], 'extract_content': [], 'cosine_degree': 0.0}, {'url': 'https://bocongan.gov.vn/tin-tuc-su-kien/hoat-dong-cua-luc-luong-cong-an/hoat-dong-cua-dia-phuong/dong-thap-dau-tranh-voi-toi-pham-te-nan-co-bac-mua-euro-nam-2024-d23-t40104.html', 'title': '', 'content': '', 'labeled_pos': [], 'extract_content': [], 'cosine_degree': 0.0}, {'url': 'http://congan.daklak.gov.vn/-/to-chuc-hoat-ong-tuyen-truyen-phong-chong-toi-pham-vi-pham-phap-luat-lien-quan-en-co-bac-ca-o-bong-a-vong-chung-ket-euro-2024', 'title': '', 'content': '', 'labeled_pos': [], 'extract_content': [], 'cosine_degree': 0.0}, {'url': 'https://congan.com.vn/vu-an/phong-su/ca-do-no-ro-mua-euro_163552.html', 'title': '', 'content': '', 'labeled_pos': [], 'extract_content': [], 'cosine_degree': 0.0}, {'url': 'https://baobinhduong.vn/phong-ngua-nan-ca-cuoc-trong-mua-euro-2024-a324538.html
# ...

# %% [markdown]
# # Trích xuất văn bản từ link

# %%
from newspaper import Config, Article

def extract_text_and_title_from_url(url):
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0'

    config = Config()
    config.browser_user_agent = user_agent
    config.request_timeout = 10

    page = Article(url, config=config)
    text = ""
    title = ""
    try:
        page.download()
        page.parse()
        text = page.text
        title = page.title
    except Exception as e:
        print(f"An error occurred: {e}")

    return title, text
i = 0
while i < len(array_of_elements):
    url = array_of_elements[i]['url']
    title, content = extract_text_and_title_from_url(url)
    
    if content:
        array_of_elements[i]['title'] = title
        array_of_elements[i]['content'] = content
        i += 1
    else:
        del array_of_elements[i]

print(array_of_elements)
# Out:
# An error occurred: Article `download()` failed with HTTPSConnectionPool(host='congan.daklak.gov.vn', port=443): Max retries exceeded with url: /-/to-chuc-hoat-ong-tuyen-truyen-phong-chong-toi-pham-vi-pham-phap-luat-lien-quan-en-co-bac-ca-o-bong-a-vong-chung-ket-euro-2024 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)'))) on URL http://congan.daklak.gov.vn/-/to-chuc-hoat-ong-tuyen-truyen-phong-chong-toi-pham-vi-pham-phap-luat-lien-quan-en-co-bac-ca-o-bong-a-vong-chung-ket-euro-2024
# ...

# %% [markdown]
# # Kiểm tra lại phần tử

# %%
print(len(array_of_elements))
# Out:
# 8

# %% [markdown]
# # Gán nhãn từ loại

# %%
import requests


def get_word_info(text):
    url = 'http://localhost:8000/words'
    data =text
    
    try:
        response = requests.post(url, data)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Request failed with status code {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return None

i = 0
while i < len(array_of_elements):
    content = array_of_elements[i]['content']
    extract_content_info = get_word_info(content)
    
    if extract_content_info is not None:
        array_of_elements[i]['labeled_pos'] = extract_content_info
        i += 1
    else:
      
        del array_of_elements[i]


print(array_of_elements)
# Out:
# [{'url': 'https://antv.gov.vn/phap-luat-3/canh-bao-te-nan-ca-cuoc-bong-da-mua-euro--9E6F5E63E.html', 'title': 'Cảnh báo tệ nạn cá cược bóng đá mùa Euro', 'content': '(ANTV) - Bộ Công an mới đây đã đưa ra cảnh báo đến người dân về tệ nạn cá độ bóng đá trong mùa giải Euro 2024. Cá độ bóng đá là hình thức cờ bạc đã tồn tại từ lâu, trong giai đoạn hiện tại lợi dụng triệt để không gian mạng hình thức và thủ đoạn của các đối tượng ngày một tinh. Tuy nhiên lực lượng công an khẳng định: Cá độ bóng đá trên mạng dù có che dấu tinh vi như thế nào cũng đều để lại dấu vết. Đồng thời Bộ Công an cũng tiếp tục đưa ra cảnh báo với người dân về những hệ lụy nguy hiểm của tệ nạn này.\n\nCảm thấy may mắn vì đã từ bỏ được cá độ bóng đá là cảm giác của anh Đào Đức L ở Cầu Diễn, Hà Nội. Từ chơi nhỏ cho vui cùng bạn bè, anh đã từng mất cả trăm triệu đồng cho những kèo độ bóng đá trên mạng.\n\nGiải trí xem bóng đá là nhu cầu chính đáng của mọi người. Nhưng trong quá trình xem cũng rất dễ để sa ngã vào con đư
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def extract_top_keywords(data):
    # Đọc danh sách stopwords từ file 'stopwords.txt'
    with open('stopwords.txt', 'r', encoding='utf-8') as f:
        stopwords = f.read().split()

    text = ' '.join(item["từ"] for item in data if item["từ"] not in stopwords)

    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform([text] if text else [""])
    feature_names = vectorizer.get_feature_names_out()
    tfidf_scores = X.toarray()[0] if text else [0] * len(feature_names)

    tfidf_dict = dict(zip(feature_names, tfidf_scores))

    sorted_tfidf = sorted(tfidf_dict.items(), key=lambda item: item[1], reverse=True)[:5]

    result = []

    for word, score in sorted_tfidf:
        try:
            loai_tu = next(item["loại từ"] for item in data if item["từ"] == word)
            result.append({"từ khóa": word, "loại từ": loai_tu, "điểm số": float(round(score, 2))})  
        except StopIteration:
            continue

    return result




i = 0
while i < len(array_of_elements):
    labeled_pos = array_of_elements[i]['labeled_pos']
    extract_content_info = extract_top_keywords(labeled_pos)
    
    if extract_content_info is not None:
        array_of_elements[i]['extract_content'] = extract_content_info
        i += 1
    else:
      
        del array_of_elements[i]

# %%
print(array_of_elements)
# Out:
# [{'url': 'https://antv.gov.vn/phap-luat-3/canh-bao-te-nan-ca-cuoc-bong-da-mua-euro--9E6F5E63E.html', 'title': 'Cảnh báo tệ nạn cá cược bóng đá mùa Euro', 'content': '(ANTV) - Bộ Công an mới đây đã đưa ra cảnh báo đến người dân về tệ nạn cá độ bóng đá trong mùa giải Euro 2024. Cá độ bóng đá là hình thức cờ bạc đã tồn tại từ lâu, trong giai đoạn hiện tại lợi dụng triệt để không gian mạng hình thức và thủ đoạn của các đối tượng ngày một tinh. Tuy nhiên lực lượng công an khẳng định: Cá độ bóng đá trên mạng dù có che dấu tinh vi như thế nào cũng đều để lại dấu vết. Đồng thời Bộ Công an cũng tiếp tục đưa ra cảnh báo với người dân về những hệ lụy nguy hiểm của tệ nạn này.\n\nCảm thấy may mắn vì đã từ bỏ được cá độ bóng đá là cảm giác của anh Đào Đức L ở Cầu Diễn, Hà Nội. Từ chơi nhỏ cho vui cùng bạn bè, anh đã từng mất cả trăm triệu đồng cho những kèo độ bóng đá trên mạng.\n\nGiải trí xem bóng đá là nhu cầu chính đáng của mọi người. Nhưng trong quá trình xem cũng rất dễ để sa ngã vào con đư
# ...

# %%
print(len(array_of_elements))
# Out:
# 8

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def calculate_cosine_similarity(array_of_elements, original_keywords):
    for element in array_of_elements:
        extracted_keywords = element['extract_content']
        
      
        all_keywords = {kw['từ khóa']: 0 for kw in extracted_keywords}
        for kw in original_keywords:
            all_keywords[kw] = 0
        
       
        extracted_vector = np.zeros(len(all_keywords))
        for kw in extracted_keywords:
            index = list(all_keywords.keys()).index(kw['từ khóa'])
            extracted_vector[index] = kw['điểm số']
        
      
        original_vector = np.zeros(len(all_keywords))
        for kw in original_keywords:
            if kw in all_keywords:
                index = list(all_keywords.keys()).index(kw)
                original_vector[index] = 1
        

        similarity = cosine_similarity([extracted_vector], [original_vector])[0][0]
    
        element['cosine_degree'] = float(round(similarity, 2))

    return array_of_elements
original_keywords = ["euro", "cờ_bạc", "bóng_đá", "tệ_nạn", "cá_cược"]
array_of_elements = calculate_cosine_similarity(array_of_elements, original_keywords)

# %%
print(extract_keywords(response))
# Out:
# ['euro', 'cờ_bạc', 'bóng_đá', 'tệ_nạn', 'cá_cược']

# %%
array_of_elements
# Out:
# [{'url': 'https://antv.gov.vn/phap-luat-3/canh-bao-te-nan-ca-cuoc-bong-da-mua-euro--9E6F5E63E.html',
#   'title': 'Cảnh báo tệ nạn cá cược bóng đá mùa Euro',
# ...

# %%
# import sqlite3
# import json

# conn = sqlite3.connect('example.db')
# cursor = conn.cursor()

# cursor.execute('''
# CREATE TABLE search_info (
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     keywords TEXT,
#     access_time TEXT,
#     completed BOOLEAN
# )
# ''')

# cursor.execute('''
# CREATE TABLE search_details (
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     search_info_id INTEGER,
#     link TEXT,
#     title TEXT,
#     content TEXT,
#     content_processed TEXT,
#     keywords_extracted TEXT,
#     confidence_level REAL,
#     FOREIGN KEY (search_info_id) REFERENCES search_info(id)
# )
# ''')


# search_info_data = [
#     {
#         "keyword": ["euro", "cờ bạc", "bóng đá", "tệ nạn", "cá cược"],
#         "access_time": "2024-07-10T10:30:00",
#         "completed": True
#     },
# ]
# for item in search_info_data:
#     cursor.execute('''
#     INSERT INTO search_info (keywords, access_time, completed)
#     VALUES (?, ?, ?)
#     ''', (','.join(item["keyword"]), item["access_time"], item["completed"]))

# i=0
# for item in array_of_elements :
#     cursor.execute('''
#     INSERT INTO search_details (
#         search_info_id, 
#         link, 
#         title, 
#         content, 
#         content_processed, 
#         keywords_extracted, 
#         confidence_level
#     )
#     VALUES (?, ?, ?, ?, ?, ?, ?)
#     ''', (1, item["url"], item.get("title", ""), item["content"], json.dumps(item.get("labeled_pos", [])), json.dumps(item.get("extract_content", [])), item.get("cosine_degree", 0.0))),
#     i=i+1
#     print(i)
    
# conn.commit()


# cursor.execute('SELECT * FROM search_info')
# search_info_rows = cursor.fetchall()

# cursor.execute('SELECT * FROM search_details')
# search_details_rows = cursor.fetchall()

# print(search_info_rows, search_details_rows)
